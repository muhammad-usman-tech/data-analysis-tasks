# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-usman-tech/data-analysis-tasks/blob/main/My_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas._libs import missing
# Task 1
# 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 3.
df=pd.read_csv('/content/Titanic-Dataset.csv')
# 4.
df.info()
df.shape #get 891 rows and the 12 attributes
df.head(10)
# inspected the data

# 5.
print('number of the rows', len(df))
print('number of the columns', df.shape[1])
print('columns name are: ',df.columns.to_list())


# 6--this is for the memory usage : 83.7+ KB found that in the df.info()
# 7-exporting
df.to_csv('Titanic-Dataset-export.csv',index=False)
df.to_json('Titanic-Dataset-export.json')
df.to_excel('Titanic-Dataset-export.xlsx')
# 8-:answered


# Task 2 from (step 9-16)
# 9-load data again
df_1=pd.read_csv('/content/Titanic-Dataset-export.csv')
df.info() #all the attributes are same and rows and columns are also the same
# 10.
missing=df_1.isnull().sum()
percent=(missing/len(df_1))*100
percent
# 11
drop=percent[percent>=50].index
df_1=df_1.drop(columns=drop)

obj_columns=df_1.select_dtypes(include=['object']).columns
obj_columns
df_1[obj_columns]=df_1[obj_columns].fillna(df_1[obj_columns].mode().iloc[0])
df_1['Age']=df_1['Age'].fillna(df_1['Age'].median())
missing=df_1.isnull().sum()
percent=(missing/len(df_1))*100
print(percent) # done

# 12.
print('==============')
df_1.duplicated().sum() # got 0
# what if want to drop duplicates so the code will be
df_1.drop_duplicates(inplace=True)

# 13. standardize the sex column
df_1['Sex']=df_1['Sex'].str.strip().str.lower()

# 14
obj_columns_2=df_1.select_dtypes(include=['object']).columns
df_1[obj_columns_2]=df_1[obj_columns_2].apply(lambda x : x.str.strip())
# 15.validating the checks

df_1.isnull().sum()
df.duplicated().sum()
# checked
# 16..
df_1.to_csv('cleaned_data.csv',index=False)
df_1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# number of the rows 891
# number of the columns 12
# columns name are:  ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# ...

# %% [markdown]
# ## **Task 3**

# %%
# Task 3(task 17-24)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 17--data set downloaded and loaded
df=pd.read_csv('/content/netflix_titles.csv')
# 18--inspecting the data set
df.info()
df.head()
df.shape # got 8807 rows and the 12 columns
missing =df.isnull().sum()
missing #yes have alot of the missing values
# 19..
df['date_added']=pd.to_datetime(df['date_added'],format='mixed')
# 20 ..extracting month, year and the days
df['added_year']=df['date_added'].dt.year
df['added_year']
df['added_month']=df['date_added'].dt.month
df['added_month']
df['added_dayof_year']=df['date_added'].dt.day_of_year
df['added_dayof_year']

# 21..
df['listed_in']=df['listed_in'].str.strip().str.lower()


# 22..
df=df.dropna(subset=['director','cast'])
# 23..
df['title']=df['title'].str.replace(r'[^A-Z-z0-9\s]', " ",regex=True)
# 24 ..
df.to_csv('cleaned_titles.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
