# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-usman-tech/data-analysis-tasks/blob/main/data_aggregation_revise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('website_wata.csv')
df.shape
df.columns
df.head()
df['Page_name']=np.random.choice(['face book','youtube','instagram',"tiktok",'snapchat'],size=len(df))

df.groupby('Page_name')['Time on Page'].sum().sort_values(ascending=False)
df.groupby('Page_name')['Page Views'].sum().sort_values(ascending=False).head(1)

# for finding the unique user's in this way because i dont have any data on wich i can count all these on the daily basis
a=df_selected=df[df['Previous Visits']==0]
df_selected.head()
print('===')
print(len(a))

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Sample - Superstore.csv',encoding='latin1')
df.shape
print(df.head())
df.dtypes
# there was no single column that shoes the price per product so temporarily i used the sales but it is the total sales and already
# counted
df['Total_Sales']=df['Quantity']*df['Sales']
df['Total_Sales']

df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
df['Product Name'] # seems like ok so not exploiding it
df.groupby('Product Name')['Quantity'].mean().sort_values(ascending=False).head(3)
# creating the summary by the month using the order date
df['Order Date']=pd.to_datetime(df['Order Date'],format='mixed')

df['Months']=df['Order Date'].dt.month_name()
df['Months']

df.groupby('Months')['Sales'].sum().sort_values(ascending=False) #nov,sep,dec got the top 3

df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('StudentsPerformance.csv')
df.shape
df.dtypes
# they mentioned marks only we can also sum all the marks first and find the avg but the simple it can be the simple avg of the math score
# student has no name so adding the name
# random data

df['name']=np.random.choice(['ali','usman','ayesha','fatima','nasir','usba'],size=len(df))
df.info()
df.groupby('name')['math score'].mean().sort_values(ascending=True)

highest_math=df['math score'].max()
highest_reading=df['reading score'].max()
highest_writting=df['writing score'].max()
highest_writting
# finding students who failed but in math
df_failed=df[df['math score']<40]
print(len(df_failed)) #40 students failed

# subject wise avg summary does not make sense here because we have different marks but can make the summary by gen
df.groupby('gender')['math score'].mean() # male got more with 68. some thing
df.groupby('gender')['reading score'].mean()  #female got more with 72. some thing
df.groupby('gender')['writing score'].mean()

# identiffing top 5 students by all marks
df['Total_score']=df['math score']+df['reading score']+df['writing score']
df.groupby('name')['Total_score'].sum().sort_values(ascending=False).head() #got all except usman
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   name                         1000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB
# 40
# name
# ayesha    38356
# nasir     35200
# fatima    34315
# ali       33085
# usba      33003
# Name: Total_score, dtype: int64

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('data.csv',encoding='latin1')

df.shape #(462115, 8) long data format

df.info()
df.head()
df['Total_Sales']=df['Quantity']*df['UnitPrice']
# total spending per cus
df.groupby('CustomerID')['Total_Sales'].sum().sort_values(ascending=False)

# for the second question i dnt have category column so using the stock code something same
df.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False)

#3 Identify top 5 customers by spending:little same like the first one
df.groupby('CustomerID')['Total_Sales'].sum().sort_values(ascending=False).head()

# 4 still not have category so using description
df.groupby('Description')['InvoiceNo'].nunique().sort_values(ascending=False).head()
# got 20 orders of PINK REGENCY TEACUP AND SAUCER	"555524"	20
#5 avg amount
avg=df['Total_Sales'].mean()
print(avg) # got 17
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# 17.98779487699964

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Sample - Superstore.csv',encoding='latin1')
df.shape
df.head()
group=df.groupby(['Region','Product Name'])

group['Quantity'].sum().sort_values(ascending=False)

group['Sales'].mean().head()
# Identify highest selling product in each region
df.groupby('Region')['Product Name'].nunique()


# Compare region-wise performance
df.groupby('Region')['Sales'].sum().sort_values(ascending=False) # west has best sales

# answer of question 3
abc=group['Sales'].sum().sort_values(ascending=False)
highest=abc.groupby(level=0).idxmax()
highest
# Out:
# Region
# Central     (Central, Canon imageCLASS 2200 Advanced Copier)
# East           (East, Canon imageCLASS 2200 Advanced Copier)
# South      (South, Cisco TelePresence System EX90 Videoco...
# West           (West, Canon imageCLASS 2200 Advanced Copier)
# Name: Sales, dtype: object

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('employee_records.csv')
df.shape # long format data(30,000,8)

df.info()
df['Joining_Date']=pd.to_datetime(df['Joining_Date'],format='mixed')
# 1
df.groupby('Department')['Salary'].mean().sort_values(ascending=False)

# 2
df.groupby('Department')['Salary'].max().sort_values(ascending=False)

# 3
df.groupby('Department')['Employee_ID'].nunique()

# 4
mean=df['Salary'].mean()
emp_above_avg=df[df['Salary']>mean]
print(len(emp_above_avg)) #total 14940 employees

# 5
df['Salary'].sum() #2694784278.3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    30000 non-null  int64
#  1   Employee_Name  30000 non-null  object
#  2   Age            30000 non-null  int64
#  3   Country        30000 non-null  object
#  4   Department     30000 non-null  object
#  5   Position       30000 non-null  object
#  6   Salary         30000 non-null  float64
#  7   Joining_Date   30000 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.8+ MB
# 14940
# np.float64(2694784278.3)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("hf://datasets/An-j96/SuperstoreData/data.csv")
df.shape #9994 good num of rows as well as 21 columns

df['Ship Date']=pd.to_datetime(df['Ship Date'],format='mixed')
null_num=df.isnull().sum()
null_num
df.info()
# calculating perventage
percentage=(null_num/len(df))*100
col=percentage[percentage>=50]
df=df.drop(columns=col)

# removing duplicates
print('=============')
count=df.duplicated().sum()
print('=============')
count
df=df.drop_duplicates()
# creating 3 aggregations
# which countrty has most
df['Country'].mode() # USA got the most
# most repeted or comming cus name or can also take the id

df['Customer ID'].mode() #WB-21850
# avg sales
df['Sales'].mean() #230 is avg sales

# multi level grouping
abc=df.groupby(['Country','Customer ID'])['Sales'].sum()
highest = abc.groupby(level=0).idxmax()
highest

# top and lower performer by the sales

top_performer=df.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).head(1)
bottom_performer=df.groupby('Customer ID')['Sales'].sum().sort_values(ascending=False).tail(1)

# summary
# actually i dot know how to make summary of these thing of any data set and what things must me mention in any thing so iam just using the .describe to tell the basic summary
df.describe()
# but may be i can tell the best sales by region it can also be a summary or the best customer or lowest customer
# in the summary i can write different interpretation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...
