# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-usman-tech/data-analysis-tasks/blob/main/lab_19(A)_interpretation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('train.csv')

# df.info()

# df['Product Name'] = df['Product Name'].str.split(',')
# df = df.explode('Product Name')
# df.shape
# df.head()
# # Task 1-dataset loaded
# # Task2 :
# print('Unique values of 2 fields')
# print(df['State'].unique())
# print(df['Ship Mode'].unique())

# # Task 3 :Apply searching/filtering on a selected category
# # filtering
# filtered_df=df[(df['State']=='California') | (df['State']== 'North Carolina') ]
# filtered_df
# # Searching
# df_new=df[df['Ship Mode'].str.contains('First Class')]
# df_new

# # Task 4
# df['Sales'].sum()
# Task 5
region_summary=df.groupby('Region')['Sales'].agg(
    Total_SALES='sum',
    Average_Sales='mean'
).sort_values('Total_SALES',ascending=False).round(2)
region_summary
# Out:
#          Total_SALES  Average_Sales
# Region
# West       710219.68         226.18
# East       669518.73         240.40
# Central    492646.91         216.36
# South      389151.46         243.52
